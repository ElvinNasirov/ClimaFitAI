# %%
# !python ../src/pipeline.py --mode full
# Out:
# Traceback (most recent call last):
#   File "C:\Users\Scc\m5-project-weather-pipeline\src\pipeline.py", line 12, in <module>
#     logging.basicConfig(
#     ~~~~~~~~~~~~~~~~~~~^
#         filename="logs/pipeline.log",
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         level=logging.INFO,
#         ^^^^^^^^^^^^^^^^^^^
#         format="%(asctime)s - %(levelname)s - %(message)s"
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "C:\Program Files\Python314\Lib\logging\__init__.py", line 2101, in basicConfig
#     h = FileHandler(filename, mode,
#                     encoding=encoding, errors=errors)
#   File "C:\Program Files\Python314\Lib\logging\__init__.py", line 1219, in __init__
#     StreamHandler.__init__(self, self._open())
#                                  ~~~~~~~~~~^^
#   File "C:\Program Files\Python314\Lib\logging\__init__.py", line 1248, in _open
#     return open_func(self.baseFilename, self.mode,
# ...
